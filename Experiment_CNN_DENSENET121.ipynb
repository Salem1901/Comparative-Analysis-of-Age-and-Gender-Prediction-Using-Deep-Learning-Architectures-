# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler

# %%
# Directories
train_dir = 'D:/Permanent/train'
test_dir = 'D:/Permanent/test'

# %%
# Load training data
image_paths = []
age_labels = []
gender_labels = []
image_ids = []

for filename in os.listdir(train_dir):
    image_path = os.path.join(train_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)
    image_ids.append(image_id)

# Convert to numpy arrays
image_ids = np.array(image_ids)
train_df = pd.DataFrame({'image': image_paths, 'age': age_labels, 'gender': gender_labels, 'image_id': image_ids})

# %%
# Plot Age and Gender Distributions
sns.histplot(train_df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

sns.countplot(x='gender', data=train_df)
plt.title("Gender Distribution")
plt.show()

# Load Images
def load_images(image_paths, target_size=(224, 224)):
    images = []
    for img_path in tqdm(image_paths):
        img = load_img(img_path, target_size=target_size, color_mode="rgb")
        img = np.array(img) / 255.0
        images.append(img)
    return np.array(images)

X_images = load_images(train_df['image'])
y_gender = np.array(train_df['gender'])
y_age = np.array(train_df['age'])
# Out:
#   0%|          | 0/358 [00:00<?, ?it/s]

# %%
# Split Train-Validation
X_train, X_val, y_train_gender, y_val_gender, y_train_age, y_val_age = train_test_split(
    X_images, y_gender, y_age, test_size=0.2, stratify=y_gender, random_state=42
)

# %%
# Balance classes for Gender Classification
ros = RandomOverSampler()
X_train_gender, y_train_gender_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_gender)
X_train_gender = X_train_gender.reshape(-1, 224, 224, 3)

# Balance classes for Age Regression
X_train_age, y_train_age_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_age)
X_train_age = X_train_age.reshape(-1, 224, 224, 3)

# %%
# Gender Model - DenseNet121
def create_gender_model(input_shape=(224, 224, 3)):
    base_model = DenseNet121(include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

gender_model = create_gender_model()
gender_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Train Gender Model
history_gender = gender_model.fit(X_train_gender, y_train_gender_balanced, validation_data=(X_val, y_val_gender),
                                  epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 19s 1s/step - loss: 1.8020 - accuracy: 0.5411 - val_loss: 1.0922 - val_accuracy: 0.5556
# Epoch 2/20
# 10/10 [==============================] - 10s 1s/step - loss: 0.7516 - accuracy: 0.5791 - val_loss: 0.5652 - val_accuracy: 0.7361
# Epoch 3/20
# 10/10 [==============================] - 10s 991ms/step - loss: 0.5084 - accuracy: 0.7247 - val_loss: 0.6520 - val_accuracy: 0.6389
# Epoch 4/20
# 10/10 [==============================] - 10s 1s/step - loss: 0.4092 - accuracy: 0.8165 - val_loss: 0.5228 - val_accuracy: 0.7083
# Epoch 5/20
# 10/10 [==============================] - 10s 1s/step - loss: 0.3125 - accuracy: 0.9051 - val_loss: 0.5061 - val_accuracy: 0.7361
# Epoch 6/20
# 10/10 [==============================] - 10s 1s/step - loss: 0.2418 - accuracy: 0.9430 - val_loss: 0.5035 - val_accuracy: 0.6806
# Epoch 7/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.2041 - accuracy: 0.9589 - val_loss: 0.5052 - val_accuracy: 0.6944
# Epoch 8/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.1652 - accuracy: 0.9810 - val_loss: 0.4716 - val_accuracy: 0.7639
# Epoch 9/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.1532 - accuracy: 0.9810 - val_loss: 0.4822 - val_accuracy: 0.7500
# Epoch 10/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.1286 - accuracy: 0.9873 - val_loss: 0.4714 - val_accuracy: 0.7639
# Epoch 11/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.1024 - accuracy: 0.9873 - val_loss: 0.4927 - val_accuracy: 0.6944
# Epoch 12/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.0822 - accuracy: 0.9937 - val_loss: 0.4908 - val_accuracy: 0.7083
# Epoch 13/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.0701 - accuracy: 0.9968 - val_loss: 0.4699 - val_accuracy: 0.7361
# Epoch 14/20
# 10/10 [==============================] - 12s 1s/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.6944
# Epoch 15/20
# 10/10 [==============================] - 12s 1s/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.7222
# Epoch 16/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.7500
# Epoch 17/20
# 10/10 [==============================] - 12s 1s/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.4777 - val_accuracy: 0.7639
# Epoch 18/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.4789 - val_accuracy: 0.7639
# Epoch 19/20
# 10/10 [==============================] - 11s 1s/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.7083
# Epoch 20/20
# 10/10 [==============================] - 13s 1s/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.4934 - val_accuracy: 0.7639

# %%
# Plot Gender Model Loss Curve
plt.figure()
plt.plot(history_gender.history['loss'], label='Train Loss')
plt.plot(history_gender.history['val_loss'], label='Validation Loss')
plt.title('DENSENET121 Gender Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('DENSENET121 Gender Model - Loss Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# Plot Gender Model Accuracy Curve
plt.figure()
plt.plot(history_gender.history['accuracy'], label='Train Accuracy')
plt.plot(history_gender.history['val_accuracy'], label='Validation Accuracy')
plt.title('DENSENET121 Gender Model - Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('DENSENET121 Gender Model - Accuracy Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# Gender Model - ROC Curve on Validation
y_val_gender_pred_prob = gender_model.predict(X_val).ravel()
val_fpr, val_tpr, _ = roc_curve(y_val_gender, y_val_gender_pred_prob)
roc_auc = auc(val_fpr, val_tpr)

plt.figure()
plt.plot(val_fpr, val_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('DENSENET121 Gender Model - ROC Curve on Validation Set')
plt.legend(loc="lower right")
plt.savefig('DENSENET121 Gender Model - ROC Curve on Validation Set.png', bbox_inches='tight')  # Save the figure
plt.show()
# Out:
# 3/3 [==============================] - 5s 733ms/step

# %%
# Age Model - DenseNet121
def create_age_model(input_shape=(224, 224, 3)):
    base_model = DenseNet121(include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(1)(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

age_model = create_age_model()
age_model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])

# Train Age Model
history_age = age_model.fit(X_train_age, y_train_age_balanced, validation_data=(X_val, y_val_age),
                            epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 44s 1s/step - loss: 391.6932 - mae: 15.7877 - val_loss: 173.8428 - val_mae: 10.6950
# Epoch 2/20
# 31/31 [==============================] - 33s 1s/step - loss: 98.9785 - mae: 7.7558 - val_loss: 137.5100 - val_mae: 9.3753
# Epoch 3/20
# 31/31 [==============================] - 35s 1s/step - loss: 49.3462 - mae: 5.4425 - val_loss: 130.8105 - val_mae: 8.9937
# Epoch 4/20
# 31/31 [==============================] - 32s 1s/step - loss: 31.1074 - mae: 4.1486 - val_loss: 124.0890 - val_mae: 8.3839
# Epoch 5/20
# 31/31 [==============================] - 33s 1s/step - loss: 23.4836 - mae: 3.5189 - val_loss: 118.9983 - val_mae: 8.3096
# Epoch 6/20
# 31/31 [==============================] - 32s 1s/step - loss: 15.7596 - mae: 2.7231 - val_loss: 116.3662 - val_mae: 8.2050
# Epoch 7/20
# 31/31 [==============================] - 31s 1s/step - loss: 11.9007 - mae: 2.3779 - val_loss: 118.7109 - val_mae: 8.4371
# Epoch 8/20
# 31/31 [==============================] - 32s 1s/step - loss: 9.6446 - mae: 2.2203 - val_loss: 114.7082 - val_mae: 7.9947
# Epoch 9/20
# 31/31 [==============================] - 32s 1s/step - loss: 7.4344 - mae: 1.9032 - val_loss: 114.3783 - val_mae: 8.1265
# Epoch 10/20
# 31/31 [==============================] - 33s 1s/step - loss: 6.0867 - mae: 1.7378 - val_loss: 114.4175 - val_mae: 8.1598
# Epoch 11/20
# 31/31 [==============================] - 32s 1s/step - loss: 4.1160 - mae: 1.2477 - val_loss: 110.9426 - val_mae: 7.8486
# Epoch 12/20
# 31/31 [==============================] - 33s 1s/step - loss: 3.2841 - mae: 1.0549 - val_loss: 110.2927 - val_mae: 7.8325
# Epoch 13/20
# 31/31 [==============================] - 33s 1s/step - loss: 2.7555 - mae: 1.0199 - val_loss: 112.4064 - val_mae: 8.0565
# Epoch 14/20
# 31/31 [==============================] - 34s 1s/step - loss: 2.5701 - mae: 1.0371 - val_loss: 110.7347 - val_mae: 7.8149
# Epoch 15/20
# 31/31 [==============================] - 31s 1s/step - loss: 1.8260 - mae: 0.8256 - val_loss: 110.8682 - val_mae: 7.8639
# Epoch 16/20
# 31/31 [==============================] - 31s 1s/step - loss: 1.3247 - mae: 0.6134 - val_loss: 111.0976 - val_mae: 7.8197
# Epoch 17/20
# 31/31 [==============================] - 31s 996ms/step - loss: 1.0857 - mae: 0.5845 - val_loss: 111.2767 - val_mae: 7.8873
# Epoch 18/20
# 31/31 [==============================] - 31s 1000ms/step - loss: 0.8715 - mae: 0.4941 - val_loss: 111.3344 - val_mae: 7.7919
# Epoch 19/20
# 31/31 [==============================] - 31s 1s/step - loss: 0.7188 - mae: 0.4515 - val_loss: 111.3975 - val_mae: 7.9102
# Epoch 20/20
# 31/31 [==============================] - 31s 998ms/step - loss: 0.5825 - mae: 0.4046 - val_loss: 111.5311 - val_mae: 7.9073

# %%
# Plot Age Model Loss Curve
plt.figure()
plt.plot(history_age.history['loss'], label='Train Loss')
plt.plot(history_age.history['val_loss'], label='Validation Loss')
plt.title('DENSENET121 Age Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('DENSENET121 Age Model - Loss Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# %%
# Load test images
test_image_paths = []
test_age_labels = []
test_gender_labels = []
test_image_ids = []

for filename in os.listdir(test_dir):
    image_path = os.path.join(test_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    test_image_paths.append(image_path)
    test_age_labels.append(age)
    test_gender_labels.append(gender)
    test_image_ids.append(image_id)

test_df = pd.DataFrame({'image': test_image_paths, 'age': test_age_labels, 'gender': test_gender_labels, 'image_id': test_image_ids})
X_test_images = load_images(test_df['image'])
y_test_gender = np.array(test_df['gender'])
y_test_age = np.array(test_df['age'])
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Gender Model - Test Set Evaluation
y_pred_gender_test_prob = gender_model.predict(X_test_images).ravel()
y_pred_gender_test = (y_pred_gender_test_prob > 0.5).astype(int)

# Calculate ROC Curve
test_fpr, test_tpr, _ = roc_curve(y_test_gender, y_pred_gender_test_prob)
test_roc_auc = auc(test_fpr, test_tpr)

# Print classification report
print("Gender Test Classification Report:\n", classification_report(y_test_gender, y_pred_gender_test))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_gender, y_pred_gender_test)
print("Confusion Matrix:\n", conf_matrix)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Female', 'Male'], yticklabels=['Female', 'Male'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('DENSENET121 Gender Model Confusion Matrix')
plt.savefig('DENSENET121 Gender Model Confusion Matrix.png', bbox_inches='tight')  # Save the figure
plt.show()

# Plot ROC Curve
plt.figure()
plt.plot(test_fpr, test_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {test_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('DENSENET121 Gender Model - ROC Curve on Test Set')
plt.legend(loc="lower right")
plt.savefig('DENSENET121 Gender Model - ROC Curve on Test Set.png', bbox_inches='tight')  # Save the figure
plt.show()
# Out:
# 3/3 [==============================] - 2s 732ms/step
# Gender Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        41
#            1       0.87      0.71      0.78        38
#
#     accuracy                           0.81        79
#    macro avg       0.82      0.81      0.81        79
# weighted avg       0.82      0.81      0.81        79
#
# Confusion Matrix:
#  [[37  4]
#  [11 27]]

# %%
# Age Model - Test Set Evaluation
y_pred_age_test = age_model.predict(X_test_images).ravel()

# Evaluation metrics for Age Model
mse_age = mean_squared_error(y_test_age, y_pred_age_test)
mae_age = mean_absolute_error(y_test_age, y_pred_age_test)
mape_age = mean_absolute_percentage_error(y_test_age, y_pred_age_test)
rmse_age = np.sqrt(mse_age)
r2_age = r2_score(y_test_age, y_pred_age_test)

print("Age Model Evaluation:")
print(f"MSE: {mse_age:.2f}")
print(f"MAE: {mae_age:.2f}")
print(f"MAPE: {mape_age * 100:.2f}%")
print(f"RMSE: {rmse_age:.2f}")
print(f"R^2: {r2_age:.2f}")

# Plotting Age Predictions
plt.figure(figsize=(10, 5))
plt.scatter(y_test_age, y_pred_age_test, alpha=0.5)
plt.plot([y_test_age.min(), y_test_age.max()], [y_test_age.min(), y_test_age.max()], 'k--', lw=2)
plt.title('Actual vs Predicted Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.show()
# Out:
# 3/3 [==============================] - 4s 712ms/step
# Age Model Evaluation:
# MSE: 97.20
# MAE: 7.95
# MAPE: 27.31%
# RMSE: 9.86
# R^2: 0.52
