# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler

# %%
# Directories
train_dir = 'D:/Permanent/train'
test_dir = 'D:/Permanent/test'

# %%
# Load training data
image_paths = []
age_labels = []
gender_labels = []
image_ids = []

for filename in os.listdir(train_dir):
    image_path = os.path.join(train_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)
    image_ids.append(image_id)

# Convert to numpy arrays
image_ids = np.array(image_ids)
train_df = pd.DataFrame({'image': image_paths, 'age': age_labels, 'gender': gender_labels, 'image_id': image_ids})

# %%
# Plot Age and Gender Distributions
sns.histplot(train_df['age'], kde=True)
plt.title("Age Distribution")
plt.savefig('Age Distribution.png', bbox_inches='tight')  # Save the figure
plt.show()

sns.countplot(x='gender', data=train_df)
plt.title("Gender Distribution")
plt.savefig('Gender Distribution.png', bbox_inches='tight')  # Save the figure
plt.show()

# Load Images
def load_images(image_paths, target_size=(224, 224)):
    images = []
    for img_path in tqdm(image_paths):
        img = load_img(img_path, target_size=target_size, color_mode="rgb")
        img = np.array(img) / 255.0
        images.append(img)
    return np.array(images)

X_images = load_images(train_df['image'])
y_gender = np.array(train_df['gender'])
y_age = np.array(train_df['age'])
# Out:
#   0%|          | 0/358 [00:00<?, ?it/s]

# %%
# Split Train-Validation
X_train, X_val, y_train_gender, y_val_gender, y_train_age, y_val_age = train_test_split(
    X_images, y_gender, y_age, test_size=0.2, stratify=y_gender, random_state=42
)

# %%
# Balance classes for Gender Classification
ros = RandomOverSampler()
X_train_gender, y_train_gender_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_gender)
X_train_gender = X_train_gender.reshape(-1, 224, 224, 3)

# Balance classes for Age Regression
X_train_age, y_train_age_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_age)
X_train_age = X_train_age.reshape(-1, 224, 224, 3)

# %%
# Gender Model - VGG19
def create_gender_model(input_shape=(224, 224, 3)):
    base_model = VGG19(include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

gender_model = create_gender_model()
gender_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Train Gender Model
history_gender = gender_model.fit(X_train_gender, y_train_gender_balanced, validation_data=(X_val, y_val_gender),
                                  epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 34s 3s/step - loss: 0.8176 - accuracy: 0.4905 - val_loss: 0.6780 - val_accuracy: 0.5556
# Epoch 2/20
# 10/10 [==============================] - 37s 4s/step - loss: 0.6643 - accuracy: 0.5728 - val_loss: 0.6960 - val_accuracy: 0.5139
# Epoch 3/20
# 10/10 [==============================] - 39s 4s/step - loss: 0.6216 - accuracy: 0.6297 - val_loss: 0.6389 - val_accuracy: 0.6111
# Epoch 4/20
# 10/10 [==============================] - 41s 4s/step - loss: 0.5577 - accuracy: 0.7690 - val_loss: 0.6240 - val_accuracy: 0.6528
# Epoch 5/20
# 10/10 [==============================] - 42s 4s/step - loss: 0.5142 - accuracy: 0.7880 - val_loss: 0.5838 - val_accuracy: 0.7361
# Epoch 6/20
# 10/10 [==============================] - 42s 4s/step - loss: 0.4882 - accuracy: 0.8006 - val_loss: 0.5822 - val_accuracy: 0.6944
# Epoch 7/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.4642 - accuracy: 0.8323 - val_loss: 0.6597 - val_accuracy: 0.5972
# Epoch 8/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.4500 - accuracy: 0.8228 - val_loss: 0.6187 - val_accuracy: 0.6667
# Epoch 9/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.4494 - accuracy: 0.7785 - val_loss: 0.5582 - val_accuracy: 0.6944
# Epoch 10/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.4143 - accuracy: 0.8449 - val_loss: 0.5715 - val_accuracy: 0.6806
# Epoch 11/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.3726 - accuracy: 0.8829 - val_loss: 0.5426 - val_accuracy: 0.7222
# Epoch 12/20
# 10/10 [==============================] - 45s 5s/step - loss: 0.3641 - accuracy: 0.8797 - val_loss: 0.5429 - val_accuracy: 0.7361
# Epoch 13/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.3344 - accuracy: 0.9114 - val_loss: 0.5395 - val_accuracy: 0.7361
# Epoch 14/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.3175 - accuracy: 0.9146 - val_loss: 0.5413 - val_accuracy: 0.7222
# Epoch 15/20
# 10/10 [==============================] - 44s 4s/step - loss: 0.3034 - accuracy: 0.9209 - val_loss: 0.5450 - val_accuracy: 0.7083
# Epoch 16/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.3003 - accuracy: 0.9146 - val_loss: 0.5389 - val_accuracy: 0.7083
# Epoch 17/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.2782 - accuracy: 0.9304 - val_loss: 0.5380 - val_accuracy: 0.7222
# Epoch 18/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.2694 - accuracy: 0.9335 - val_loss: 0.5316 - val_accuracy: 0.7222
# Epoch 19/20
# 10/10 [==============================] - 43s 4s/step - loss: 0.2617 - accuracy: 0.9430 - val_loss: 0.5307 - val_accuracy: 0.7361
# Epoch 20/20
# 10/10 [==============================] - 44s 4s/step - loss: 0.2504 - accuracy: 0.9367 - val_loss: 0.5343 - val_accuracy: 0.7361

# %%
# Plot Gender Model Loss Curve
plt.figure()
plt.plot(history_gender.history['loss'], label='Train Loss')
plt.plot(history_gender.history['val_loss'], label='Validation Loss')
plt.title('VGGT19 Gender Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('VGGT19 Gender Model - Loss Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# Plot Gender Model Accuracy Curve
plt.figure()
plt.plot(history_gender.history['accuracy'], label='Train Accuracy')
plt.plot(history_gender.history['val_accuracy'], label='Validation Accuracy')
plt.title('VGGT19 Gender Model - Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('VGGT19 Gender Model - Accuracy Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# Gender Model - ROC Curve on Validation
y_val_gender_pred_prob = gender_model.predict(X_val).ravel()
val_fpr, val_tpr, _ = roc_curve(y_val_gender, y_val_gender_pred_prob)
roc_auc = auc(val_fpr, val_tpr)

plt.figure()
plt.plot(val_fpr, val_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('VGGT19 Gender Model - ROC Curve on Validation Set')
plt.legend(loc="lower right")
plt.savefig('VGGT19 Gender Model - ROC Curve on Validation Set.png', bbox_inches='tight')  # Save the figure
plt.show()
# Out:
# 3/3 [==============================] - 8s 2s/step

# %%
# Age Model - VGG19
def create_age_model(input_shape=(224, 224, 3)):
    base_model = VGG19(include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(1)(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

age_model = create_age_model()
age_model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])

# Train Age Model
history_age = age_model.fit(X_train_age, y_train_age_balanced, validation_data=(X_val, y_val_age),
                            epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 118s 4s/step - loss: 813.7663 - mae: 23.3579 - val_loss: 470.2285 - val_mae: 17.8904
# Epoch 2/20
# 31/31 [==============================] - 126s 4s/step - loss: 419.4865 - mae: 17.5975 - val_loss: 356.3051 - val_mae: 15.7909
# Epoch 3/20
# 31/31 [==============================] - 136s 4s/step - loss: 365.6243 - mae: 16.4964 - val_loss: 339.4793 - val_mae: 15.5931
# Epoch 4/20
# 31/31 [==============================] - 126s 4s/step - loss: 321.4477 - mae: 15.5993 - val_loss: 288.5455 - val_mae: 14.4278
# Epoch 5/20
# 31/31 [==============================] - 135s 4s/step - loss: 285.1251 - mae: 14.7265 - val_loss: 268.7213 - val_mae: 14.0177
# Epoch 6/20
# 31/31 [==============================] - 136s 4s/step - loss: 251.5450 - mae: 13.8335 - val_loss: 241.9323 - val_mae: 13.2444
# Epoch 7/20
# 31/31 [==============================] - 134s 4s/step - loss: 224.2605 - mae: 13.0004 - val_loss: 233.1190 - val_mae: 13.0297
# Epoch 8/20
# 31/31 [==============================] - 129s 4s/step - loss: 199.6801 - mae: 12.2029 - val_loss: 225.3664 - val_mae: 12.7655
# Epoch 9/20
# 31/31 [==============================] - 123s 4s/step - loss: 180.0147 - mae: 11.4238 - val_loss: 219.3374 - val_mae: 12.5257
# Epoch 10/20
# 31/31 [==============================] - 128s 4s/step - loss: 164.2081 - mae: 10.8568 - val_loss: 198.8415 - val_mae: 11.6949
# Epoch 11/20
# 31/31 [==============================] - 118s 4s/step - loss: 150.2168 - mae: 10.3144 - val_loss: 185.0444 - val_mae: 11.0403
# Epoch 12/20
# 31/31 [==============================] - 124s 4s/step - loss: 141.1406 - mae: 9.8938 - val_loss: 187.3834 - val_mae: 11.1468
# Epoch 13/20
# 31/31 [==============================] - 134s 4s/step - loss: 128.6155 - mae: 9.5227 - val_loss: 173.6445 - val_mae: 10.4703
# Epoch 14/20
# 31/31 [==============================] - 126s 4s/step - loss: 119.5137 - mae: 9.0767 - val_loss: 170.6422 - val_mae: 10.3226
# Epoch 15/20
# 31/31 [==============================] - 127s 4s/step - loss: 111.5586 - mae: 8.7318 - val_loss: 168.1518 - val_mae: 10.2206
# Epoch 16/20
# 31/31 [==============================] - 124s 4s/step - loss: 104.0212 - mae: 8.4014 - val_loss: 165.0695 - val_mae: 10.0584
# Epoch 17/20
# 31/31 [==============================] - 126s 4s/step - loss: 97.2410 - mae: 8.0665 - val_loss: 176.1322 - val_mae: 10.6435
# Epoch 18/20
# 31/31 [==============================] - 130s 4s/step - loss: 91.0459 - mae: 7.7654 - val_loss: 164.1385 - val_mae: 10.0937
# Epoch 19/20
# 31/31 [==============================] - 124s 4s/step - loss: 86.5532 - mae: 7.6283 - val_loss: 152.4687 - val_mae: 9.2710
# Epoch 20/20
# 31/31 [==============================] - 126s 4s/step - loss: 82.5881 - mae: 7.3372 - val_loss: 150.4380 - val_mae: 9.1423

# %%
# Plot Age Model Loss Curve
plt.figure()
plt.plot(history_age.history['loss'], label='Train Loss')
plt.plot(history_age.history['val_loss'], label='Validation Loss')
plt.title('VGGT19 Age Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('VGGT19 Age Model - Loss Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# %%
# Load test images
test_image_paths = []
test_age_labels = []
test_gender_labels = []
test_image_ids = []

for filename in os.listdir(test_dir):
    image_path = os.path.join(test_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    test_image_paths.append(image_path)
    test_age_labels.append(age)
    test_gender_labels.append(gender)
    test_image_ids.append(image_id)

test_df = pd.DataFrame({'image': test_image_paths, 'age': test_age_labels, 'gender': test_gender_labels, 'image_id': test_image_ids})
X_test_images = load_images(test_df['image'])
y_test_gender = np.array(test_df['gender'])
y_test_age = np.array(test_df['age'])
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Gender Model - Test Set Evaluation
y_pred_gender_test_prob = gender_model.predict(X_test_images).ravel()
y_pred_gender_test = (y_pred_gender_test_prob > 0.5).astype(int)

# Calculate ROC Curve
test_fpr, test_tpr, _ = roc_curve(y_test_gender, y_pred_gender_test_prob)
test_roc_auc = auc(test_fpr, test_tpr)

# Print classification report
print("Gender Test Classification Report:\n", classification_report(y_test_gender, y_pred_gender_test))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_gender, y_pred_gender_test)
print("Confusion Matrix:\n", conf_matrix)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Female', 'Male'], yticklabels=['Female', 'Male'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('VGGT19 Gender Model Confusion Matrix')
plt.savefig('VGGT19 Gender Model Confusion Matrix.png', bbox_inches='tight')  # Save the figure
plt.show()

# Plot ROC Curve
plt.figure()
plt.plot(test_fpr, test_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {test_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('VGGT19 Gender Model - ROC Curve on Test Set')
plt.legend(loc="lower right")
plt.savefig('VGGT19 Gender Model - ROC Curve on Test Set.png', bbox_inches='tight')  # Save the figure
plt.show()
# Out:
# 3/3 [==============================] - 9s 3s/step
# Gender Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81        41
#            1       0.86      0.66      0.75        38
#
#     accuracy                           0.78        79
#    macro avg       0.80      0.78      0.78        79
# weighted avg       0.80      0.78      0.78        79
#
# Confusion Matrix:
#  [[37  4]
#  [13 25]]

# %%
# Age Model - Test Set Evaluation
y_pred_age_test = age_model.predict(X_test_images).ravel()

# Evaluation metrics for Age Model
mse_age = mean_squared_error(y_test_age, y_pred_age_test)
mae_age = mean_absolute_error(y_test_age, y_pred_age_test)
mape_age = mean_absolute_percentage_error(y_test_age, y_pred_age_test)
rmse_age = np.sqrt(mse_age)
r2_age = r2_score(y_test_age, y_pred_age_test)

print("Age Model Evaluation:")
print(f"MSE: {mse_age:.2f}")
print(f"MAE: {mae_age:.2f}")
print(f"MAPE: {mape_age * 100:.2f}%")
print(f"RMSE: {rmse_age:.2f}")
print(f"R^2: {r2_age:.2f}")

# Plotting Age Predictions
plt.figure(figsize=(10, 5))
plt.scatter(y_test_age, y_pred_age_test, alpha=0.5)
plt.plot([y_test_age.min(), y_test_age.max()], [y_test_age.min(), y_test_age.max()], 'k--', lw=2)
plt.title('Actual vs Predicted Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.show()
# Out:
# 3/3 [==============================] - 9s 3s/step
# Age Model Evaluation:
# MSE: 142.13
# MAE: 9.57
# MAPE: 33.83%
# RMSE: 11.92
# R^2: 0.29
