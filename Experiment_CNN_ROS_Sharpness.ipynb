# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler
from PIL import Image, ImageEnhance

# %%
# Directories
train_dir = 'D:/Permanent/train'
test_dir = 'D:/Permanent/test'

# %%
# Load training data
image_paths = []
age_labels = []
gender_labels = []
image_ids = []

for filename in os.listdir(train_dir):
    image_path = os.path.join(train_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)
    image_ids.append(image_id)

image_ids = np.array(image_ids)
train_df = pd.DataFrame({'image': image_paths, 'age': age_labels, 'gender': gender_labels, 'image_id': image_ids})
# Exploratory Data Analysis
sns.histplot(train_df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

sns.countplot(x='gender', data=train_df)
plt.title("Gender Distribution")
plt.show()

# %%
# Load and preprocess images in grayscale with contrast and sharpness adjustments
def load_images(image_paths, target_size=(224, 224), contrast_factor=1.5, sharpness_factor=1.5):
    images = []
    for img_path in tqdm(image_paths):
        img = Image.open(img_path).convert("L")  # Convert to grayscale
        img = img.resize(target_size)

        # Increase contrast
        enhancer_contrast = ImageEnhance.Contrast(img)
        img = enhancer_contrast.enhance(contrast_factor)

        # Increase sharpness
        enhancer_sharpness = ImageEnhance.Sharpness(img)
        img = enhancer_sharpness.enhance(sharpness_factor)

        img = np.array(img) / 255.0  # Normalize the image
        img = np.expand_dims(img, axis=-1)  # Expand dimensions to (224, 224, 1)
        images.append(img)
    return np.array(images)

# Load images with preprocessing
X_images = load_images(train_df['image'])
y_gender = np.array(train_df['gender'])
y_age = np.array(train_df['age'])
# Out:
#   0%|          | 0/358 [00:00<?, ?it/s]

# %%
# Split Train-Validation
X_train, X_val, y_train_gender, y_val_gender, y_train_age, y_val_age = train_test_split(
    X_images, y_gender, y_age, test_size=0.2, stratify=y_gender, random_state=42
)

# %%
# Balance classes for Gender Classification
ros = RandomOverSampler()
X_train_gender, y_train_gender_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_gender)
X_train_gender = X_train_gender.reshape(-1, 224, 224, 1)

# Balance classes for Age Regression
X_train_age, y_train_age_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_age)
X_train_age = X_train_age.reshape(-1, 224, 224, 1)

# %%
# Gender Model
def create_gender_model(input_shape=(224, 224, 1)):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)
    model = Model(inputs, output)
    return model

gender_model = create_gender_model()
gender_model.compile(optimizer=Adam(learning_rate=0.00005), loss='binary_crossentropy', metrics=['accuracy'])

# Train Gender Model
history_gender = gender_model.fit(X_train_gender, y_train_gender_balanced, validation_data=(X_val, y_val_gender),
                                  epochs=40, batch_size=32)
# Out:
# Epoch 1/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.6893 - accuracy: 0.4968 - val_loss: 0.6818 - val_accuracy: 0.5694
# Epoch 2/40
# 10/10 [==============================] - 19s 2s/step - loss: 0.6680 - accuracy: 0.6108 - val_loss: 0.6560 - val_accuracy: 0.6111
# Epoch 3/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.6345 - accuracy: 0.6551 - val_loss: 0.6357 - val_accuracy: 0.6250
# Epoch 4/40
# 10/10 [==============================] - 20s 2s/step - loss: 0.6263 - accuracy: 0.6329 - val_loss: 0.6805 - val_accuracy: 0.5833
# Epoch 5/40
# 10/10 [==============================] - 19s 2s/step - loss: 0.5665 - accuracy: 0.7278 - val_loss: 0.6118 - val_accuracy: 0.6528
# Epoch 6/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.5626 - accuracy: 0.7278 - val_loss: 0.5994 - val_accuracy: 0.6389
# Epoch 7/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.5257 - accuracy: 0.7563 - val_loss: 0.6288 - val_accuracy: 0.6111
# Epoch 8/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.5298 - accuracy: 0.7532 - val_loss: 0.5831 - val_accuracy: 0.6250
# Epoch 9/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.4863 - accuracy: 0.7753 - val_loss: 0.5760 - val_accuracy: 0.6528
# Epoch 10/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.4662 - accuracy: 0.8165 - val_loss: 0.5529 - val_accuracy: 0.6528
# Epoch 11/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.4426 - accuracy: 0.7911 - val_loss: 0.5512 - val_accuracy: 0.6944
# Epoch 12/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.4167 - accuracy: 0.8323 - val_loss: 0.5348 - val_accuracy: 0.7361
# Epoch 13/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.3839 - accuracy: 0.8354 - val_loss: 0.5251 - val_accuracy: 0.7083
# Epoch 14/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.3712 - accuracy: 0.8671 - val_loss: 0.5121 - val_accuracy: 0.7778
# Epoch 15/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.3307 - accuracy: 0.8797 - val_loss: 0.5162 - val_accuracy: 0.7500
# Epoch 16/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.3262 - accuracy: 0.8703 - val_loss: 0.5279 - val_accuracy: 0.7500
# Epoch 17/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.2908 - accuracy: 0.8924 - val_loss: 0.5005 - val_accuracy: 0.7222
# Epoch 18/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.2672 - accuracy: 0.8829 - val_loss: 0.5013 - val_accuracy: 0.7083
# Epoch 19/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.2397 - accuracy: 0.9114 - val_loss: 0.5201 - val_accuracy: 0.7639
# Epoch 20/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.2190 - accuracy: 0.9335 - val_loss: 0.5315 - val_accuracy: 0.7639
# Epoch 21/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.2302 - accuracy: 0.8924 - val_loss: 0.5032 - val_accuracy: 0.7083
# Epoch 22/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.2097 - accuracy: 0.9241 - val_loss: 0.4851 - val_accuracy: 0.7639
# Epoch 23/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.1747 - accuracy: 0.9494 - val_loss: 0.5423 - val_accuracy: 0.7222
# Epoch 24/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.1644 - accuracy: 0.9652 - val_loss: 0.5408 - val_accuracy: 0.7500
# Epoch 25/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.1242 - accuracy: 0.9620 - val_loss: 0.5844 - val_accuracy: 0.7361
# Epoch 26/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.1545 - accuracy: 0.9494 - val_loss: 0.5542 - val_accuracy: 0.7361
# Epoch 27/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.1333 - accuracy: 0.9684 - val_loss: 0.5392 - val_accuracy: 0.7500
# Epoch 28/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.1009 - accuracy: 0.9810 - val_loss: 0.5928 - val_accuracy: 0.7222
# Epoch 29/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.1094 - accuracy: 0.9684 - val_loss: 0.6272 - val_accuracy: 0.7361
# Epoch 30/40
# 10/10 [==============================] - 20s 2s/step - loss: 0.1271 - accuracy: 0.9620 - val_loss: 0.5420 - val_accuracy: 0.7778
# Epoch 31/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.0846 - accuracy: 0.9810 - val_loss: 0.6243 - val_accuracy: 0.7361
# Epoch 32/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.0966 - accuracy: 0.9684 - val_loss: 0.6860 - val_accuracy: 0.7361
# Epoch 33/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.1038 - accuracy: 0.9778 - val_loss: 0.5979 - val_accuracy: 0.7500
# Epoch 34/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.0776 - accuracy: 0.9842 - val_loss: 0.6151 - val_accuracy: 0.7639
# Epoch 35/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.0706 - accuracy: 0.9842 - val_loss: 0.6438 - val_accuracy: 0.7778
# Epoch 36/40
# 10/10 [==============================] - 21s 2s/step - loss: 0.0708 - accuracy: 0.9842 - val_loss: 0.6922 - val_accuracy: 0.7361
# Epoch 37/40
# 10/10 [==============================] - 20s 2s/step - loss: 0.0532 - accuracy: 0.9873 - val_loss: 0.6408 - val_accuracy: 0.7639
# Epoch 38/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.0465 - accuracy: 0.9968 - val_loss: 0.6443 - val_accuracy: 0.7500
# Epoch 39/40
# 10/10 [==============================] - 22s 2s/step - loss: 0.0489 - accuracy: 0.9905 - val_loss: 0.6505 - val_accuracy: 0.7500
# Epoch 40/40
# 10/10 [==============================] - 23s 2s/step - loss: 0.0406 - accuracy: 0.9905 - val_loss: 0.7025 - val_accuracy: 0.7778

# %%
# Plot Gender Model Loss and Accuracy Curves
plt.figure()
plt.plot(history_gender.history['loss'], label='Train Loss')
plt.plot(history_gender.history['val_loss'], label='Validation Loss')
plt.title('Gender Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_gender.history['accuracy'], label='Train Accuracy')
plt.plot(history_gender.history['val_accuracy'], label='Validation Accuracy')
plt.title('Gender Model - Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Gender Model - ROC Curve on Validation
y_val_gender_pred_prob = gender_model.predict(X_val).ravel()
val_fpr, val_tpr, _ = roc_curve(y_val_gender, y_val_gender_pred_prob)
roc_auc = auc(val_fpr, val_tpr)

plt.figure()
plt.plot(val_fpr, val_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Gender Model - ROC Curve on Validation Set')
plt.legend(loc="lower right")
plt.show()
# Out:
# 3/3 [==============================] - 1s 240ms/step

# %%
# Age Model
def create_age_model(input_shape=(224, 224, 1)):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(1)(x)
    model = Model(inputs, output)
    return model

age_model = create_age_model()
age_model.compile(optimizer=Adam(learning_rate=0.00005), loss='mse', metrics=['mae'])

# Train Age Model
history_age = age_model.fit(X_train_age, y_train_age_balanced, validation_data=(X_val, y_val_age),
                            epochs=40, batch_size=32)
# Out:
# Epoch 1/40
# 31/31 [==============================] - 65s 2s/step - loss: 996.0809 - mae: 25.6811 - val_loss: 359.4575 - val_mae: 15.7020
# Epoch 2/40
# 31/31 [==============================] - 61s 2s/step - loss: 461.5048 - mae: 18.1168 - val_loss: 380.5362 - val_mae: 16.3413
# Epoch 3/40
# 31/31 [==============================] - 63s 2s/step - loss: 417.5555 - mae: 17.1431 - val_loss: 313.0395 - val_mae: 14.9708
# Epoch 4/40
# 31/31 [==============================] - 63s 2s/step - loss: 351.2079 - mae: 15.9117 - val_loss: 251.8043 - val_mae: 13.3785
# Epoch 5/40
# 31/31 [==============================] - 60s 2s/step - loss: 310.3445 - mae: 14.7585 - val_loss: 223.2882 - val_mae: 12.6261
# Epoch 6/40
# 31/31 [==============================] - 60s 2s/step - loss: 276.6403 - mae: 13.6214 - val_loss: 216.5951 - val_mae: 12.2980
# Epoch 7/40
# 31/31 [==============================] - 59s 2s/step - loss: 243.5899 - mae: 12.6131 - val_loss: 195.1961 - val_mae: 11.2256
# Epoch 8/40
# 31/31 [==============================] - 60s 2s/step - loss: 203.1855 - mae: 11.4196 - val_loss: 169.2005 - val_mae: 9.5186
# Epoch 9/40
# 31/31 [==============================] - 63s 2s/step - loss: 196.2519 - mae: 10.9407 - val_loss: 163.4841 - val_mae: 9.3683
# Epoch 10/40
# 31/31 [==============================] - 61s 2s/step - loss: 201.5891 - mae: 10.9353 - val_loss: 168.3125 - val_mae: 9.8263
# Epoch 11/40
# 31/31 [==============================] - 60s 2s/step - loss: 165.5888 - mae: 9.9645 - val_loss: 171.0506 - val_mae: 9.7534
# Epoch 12/40
# 31/31 [==============================] - 60s 2s/step - loss: 154.2525 - mae: 9.4842 - val_loss: 165.7468 - val_mae: 9.4650
# Epoch 13/40
# 31/31 [==============================] - 60s 2s/step - loss: 150.6786 - mae: 9.4182 - val_loss: 171.7092 - val_mae: 9.6769
# Epoch 14/40
# 31/31 [==============================] - 60s 2s/step - loss: 140.1634 - mae: 8.9973 - val_loss: 164.4344 - val_mae: 9.2712
# Epoch 15/40
# 31/31 [==============================] - 60s 2s/step - loss: 139.0987 - mae: 9.0904 - val_loss: 162.1679 - val_mae: 9.2343
# Epoch 16/40
# 31/31 [==============================] - 63s 2s/step - loss: 135.7207 - mae: 8.8357 - val_loss: 166.3713 - val_mae: 9.3255
# Epoch 17/40
# 31/31 [==============================] - 64s 2s/step - loss: 138.3828 - mae: 8.8424 - val_loss: 160.9269 - val_mae: 9.2521
# Epoch 18/40
# 31/31 [==============================] - 59s 2s/step - loss: 130.0478 - mae: 8.6699 - val_loss: 179.2120 - val_mae: 9.7327
# Epoch 19/40
# 31/31 [==============================] - 60s 2s/step - loss: 119.5904 - mae: 8.3036 - val_loss: 160.1617 - val_mae: 9.2210
# Epoch 20/40
# 31/31 [==============================] - 60s 2s/step - loss: 109.4127 - mae: 7.9852 - val_loss: 158.3720 - val_mae: 9.0561
# Epoch 21/40
# 31/31 [==============================] - 61s 2s/step - loss: 122.3688 - mae: 8.5005 - val_loss: 157.0728 - val_mae: 9.2465
# Epoch 22/40
# 31/31 [==============================] - 61s 2s/step - loss: 112.3549 - mae: 7.9363 - val_loss: 161.6610 - val_mae: 9.2935
# Epoch 23/40
# 31/31 [==============================] - 61s 2s/step - loss: 111.9982 - mae: 8.0266 - val_loss: 155.0890 - val_mae: 8.9249
# Epoch 24/40
# 31/31 [==============================] - 61s 2s/step - loss: 106.7092 - mae: 7.7455 - val_loss: 153.3462 - val_mae: 9.0113
# Epoch 25/40
# 31/31 [==============================] - 62s 2s/step - loss: 101.5994 - mae: 7.6801 - val_loss: 152.7080 - val_mae: 8.9215
# Epoch 26/40
# 31/31 [==============================] - 61s 2s/step - loss: 98.8899 - mae: 7.4790 - val_loss: 153.5560 - val_mae: 9.1245
# Epoch 27/40
# 31/31 [==============================] - 62s 2s/step - loss: 98.0818 - mae: 7.4592 - val_loss: 151.5875 - val_mae: 8.8366
# Epoch 28/40
# 31/31 [==============================] - 62s 2s/step - loss: 96.2049 - mae: 7.3539 - val_loss: 157.7084 - val_mae: 9.1424
# Epoch 29/40
# 31/31 [==============================] - 61s 2s/step - loss: 98.2199 - mae: 7.5449 - val_loss: 149.6696 - val_mae: 8.8753
# Epoch 30/40
# 31/31 [==============================] - 61s 2s/step - loss: 92.1645 - mae: 7.3406 - val_loss: 146.9735 - val_mae: 8.8724
# Epoch 31/40
# 31/31 [==============================] - 64s 2s/step - loss: 90.6312 - mae: 7.1670 - val_loss: 148.9786 - val_mae: 9.0811
# Epoch 32/40
# 31/31 [==============================] - 60s 2s/step - loss: 91.6315 - mae: 7.3670 - val_loss: 145.4422 - val_mae: 8.8815
# Epoch 33/40
# 31/31 [==============================] - 61s 2s/step - loss: 98.9059 - mae: 7.3700 - val_loss: 160.3607 - val_mae: 9.1932
# Epoch 34/40
# 31/31 [==============================] - 61s 2s/step - loss: 85.6344 - mae: 6.9978 - val_loss: 154.5338 - val_mae: 9.0413
# Epoch 35/40
# 31/31 [==============================] - 61s 2s/step - loss: 76.1072 - mae: 6.6687 - val_loss: 145.5282 - val_mae: 9.0226
# Epoch 36/40
# 31/31 [==============================] - 61s 2s/step - loss: 74.9535 - mae: 6.5651 - val_loss: 149.0127 - val_mae: 9.0240
# Epoch 37/40
# 31/31 [==============================] - 63s 2s/step - loss: 82.1841 - mae: 6.7989 - val_loss: 152.3516 - val_mae: 9.0464
# Epoch 38/40
# 31/31 [==============================] - 61s 2s/step - loss: 79.1848 - mae: 6.8128 - val_loss: 160.2940 - val_mae: 9.2887
# Epoch 39/40
# 31/31 [==============================] - 61s 2s/step - loss: 76.1017 - mae: 6.5508 - val_loss: 150.7758 - val_mae: 9.0929
# Epoch 40/40
# 31/31 [==============================] - 61s 2s/step - loss: 77.9889 - mae: 6.6636 - val_loss: 149.6259 - val_mae: 9.0590

# %%
# Plot Age Model Loss Curve
plt.figure()
plt.plot(history_age.history['loss'], label='Train Loss')
plt.plot(history_age.history['val_loss'], label='Validation Loss')
plt.title('Age Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Load test images
test_image_paths = []
test_age_labels = []
test_gender_labels = []
test_image_ids = []  # Define an array for test image IDs

for filename in os.listdir(test_dir):
    image_path = os.path.join(test_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]  # Extracting image ID
    gender = int(temp[1])
    age = int(temp[2].split()[0])  # Extracting age from filename
    test_image_paths.append(image_path)
    test_age_labels.append(age)
    test_gender_labels.append(gender)
    test_image_ids.append(image_id)  # Store test image IDs

# Convert to numpy arrays
test_image_ids = np.array(test_image_ids)
test_df = pd.DataFrame({'image': test_image_paths, 'age': test_age_labels, 'gender': test_gender_labels, 'image_id': test_image_ids})
X_test_images = load_images(test_df['image'])
y_test_gender = np.array(test_df['gender'])
y_test_age = np.array(test_df['age'])
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Gender Model - Test Set Evaluation
y_pred_gender_test_prob = gender_model.predict(X_test_images).ravel()
y_pred_gender_test = (y_pred_gender_test_prob > 0.5).astype(int)

# Calculate ROC Curve
test_fpr, test_tpr, _ = roc_curve(y_test_gender, y_pred_gender_test_prob)
test_roc_auc = auc(test_fpr, test_tpr)

# Print classification report
print("Gender Test Classification Report:\n", classification_report(y_test_gender, y_pred_gender_test))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_gender, y_pred_gender_test)
print("Confusion Matrix:\n", conf_matrix)

# Plotting the Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Female', 'Male'], yticklabels=['Female', 'Male'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix - Gender Model')
plt.show()

# Plot ROC Curve
plt.figure()
plt.plot(test_fpr, test_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {test_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Gender Model - ROC Curve on Test Set')
plt.legend(loc="lower right")
plt.show()
# Out:
# 3/3 [==============================] - 1s 323ms/step
# Gender Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        41
#            1       0.85      0.74      0.79        38
#
#     accuracy                           0.81        79
#    macro avg       0.82      0.81      0.81        79
# weighted avg       0.81      0.81      0.81        79
#
# Confusion Matrix:
#  [[36  5]
#  [10 28]]

# %%
# Age Model - Test Set Evaluation
y_pred_age_test = age_model.predict(X_test_images).ravel()

# Evaluation metrics for Age Model
mse_age = mean_squared_error(y_test_age, y_pred_age_test)
mae_age = mean_absolute_error(y_test_age, y_pred_age_test)
rmse_age = np.sqrt(mse_age)  # Calculating RMSE
r2_age = r2_score(y_test_age, y_pred_age_test)

# Calculate MAPE
mape_age = np.mean(np.abs((y_test_age - y_pred_age_test) / y_test_age)) * 100  # MAPE calculation

# Print evaluation results
print(f"Age Model Evaluation:")
print(f"MSE: {mse_age:.2f}")
print(f"MAE: {mae_age:.2f}")
print(f"RMSE: {rmse_age:.2f}")
print(f"R²: {r2_age:.2f}")
print(f"MAPE: {mape_age:.2f}%")
# Out:
# 3/3 [==============================] - 1s 277ms/step
# Age Model Evaluation:
# MSE: 122.93
# MAE: 8.49
# RMSE: 11.09
# R²: 0.39
# MAPE: 27.46%
