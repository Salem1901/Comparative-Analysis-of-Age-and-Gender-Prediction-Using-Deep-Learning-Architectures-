# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet101  # Changed to ResNet101
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler

# %%
# Directories
train_dir = 'D:/Permanent/train'
test_dir = 'D:/Permanent/test'

# %%
# Load training data
image_paths = []
age_labels = []
gender_labels = []
image_ids = []

for filename in os.listdir(train_dir):
    image_path = os.path.join(train_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    image_paths.append(image_path)
    age_labels.append(age)
    gender_labels.append(gender)
    image_ids.append(image_id)

# Convert to numpy arrays
image_ids = np.array(image_ids)
train_df = pd.DataFrame({'image': image_paths, 'age': age_labels, 'gender': gender_labels, 'image_id': image_ids})

# %%
# Plot Age and Gender Distributions
sns.histplot(train_df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

sns.countplot(x='gender', data=train_df)
plt.title("Gender Distribution")
plt.show()

# Load Images
def load_images(image_paths, target_size=(224, 224)):
    images = []
    for img_path in tqdm(image_paths):
        img = load_img(img_path, target_size=target_size, color_mode="rgb")
        img = np.array(img) / 255.0
        images.append(img)
    return np.array(images)

X_images = load_images(train_df['image'])
y_gender = np.array(train_df['gender'])
y_age = np.array(train_df['age'])
# Out:
#   0%|          | 0/358 [00:00<?, ?it/s]

# %%
# Split Train-Validation
X_train, X_val, y_train_gender, y_val_gender, y_train_age, y_val_age = train_test_split(
    X_images, y_gender, y_age, test_size=0.2, stratify=y_gender, random_state=42
)

# %%
# Balance classes for Gender Classification
ros = RandomOverSampler()
X_train_gender, y_train_gender_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_gender)
X_train_gender = X_train_gender.reshape(-1, 224, 224, 3)

# Balance classes for Age Regression
X_train_age, y_train_age_balanced = ros.fit_resample(X_train.reshape(len(X_train), -1), y_train_age)
X_train_age = X_train_age.reshape(-1, 224, 224, 3)

# %%
# Gender Model - ResNet101
def create_gender_model(input_shape=(224, 224, 3)):
    base_model = ResNet101(include_top=False, input_shape=input_shape)  # Changed to ResNet101
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

gender_model = create_gender_model()
gender_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Train Gender Model
history_gender = gender_model.fit(X_train_gender, y_train_gender_balanced, validation_data=(X_val, y_val_gender),
                                  epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 32s 2s/step - loss: 1.2424 - accuracy: 0.4937 - val_loss: 0.9857 - val_accuracy: 0.4444
# Epoch 2/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.8190 - accuracy: 0.5380 - val_loss: 0.7062 - val_accuracy: 0.5556
# Epoch 3/20
# 10/10 [==============================] - 21s 2s/step - loss: 0.7130 - accuracy: 0.5475 - val_loss: 0.7110 - val_accuracy: 0.5556
# Epoch 4/20
# 10/10 [==============================] - 21s 2s/step - loss: 0.6901 - accuracy: 0.5032 - val_loss: 0.6745 - val_accuracy: 0.5556
# Epoch 5/20
# 10/10 [==============================] - 24s 2s/step - loss: 0.6700 - accuracy: 0.5823 - val_loss: 0.6923 - val_accuracy: 0.4444
# Epoch 6/20
# 10/10 [==============================] - 22s 2s/step - loss: 0.6590 - accuracy: 0.5696 - val_loss: 0.6682 - val_accuracy: 0.5694
# Epoch 7/20
# 10/10 [==============================] - 22s 2s/step - loss: 0.6921 - accuracy: 0.5506 - val_loss: 0.6978 - val_accuracy: 0.5556
# Epoch 8/20
# 10/10 [==============================] - 22s 2s/step - loss: 0.6817 - accuracy: 0.5475 - val_loss: 0.6601 - val_accuracy: 0.6944
# Epoch 9/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.6599 - accuracy: 0.5728 - val_loss: 0.6935 - val_accuracy: 0.5556
# Epoch 10/20
# 10/10 [==============================] - 27s 3s/step - loss: 0.6415 - accuracy: 0.6044 - val_loss: 0.6693 - val_accuracy: 0.5694
# Epoch 11/20
# 10/10 [==============================] - 24s 2s/step - loss: 0.6185 - accuracy: 0.6646 - val_loss: 0.6534 - val_accuracy: 0.6944
# Epoch 12/20
# 10/10 [==============================] - 24s 2s/step - loss: 0.6218 - accuracy: 0.6582 - val_loss: 0.6606 - val_accuracy: 0.5556
# Epoch 13/20
# 10/10 [==============================] - 24s 2s/step - loss: 0.6165 - accuracy: 0.6835 - val_loss: 0.6627 - val_accuracy: 0.5417
# Epoch 14/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.5915 - accuracy: 0.6962 - val_loss: 0.6819 - val_accuracy: 0.4861
# Epoch 15/20
# 10/10 [==============================] - 25s 3s/step - loss: 0.6046 - accuracy: 0.6709 - val_loss: 0.7500 - val_accuracy: 0.4583
# Epoch 16/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.6048 - accuracy: 0.7247 - val_loss: 0.6428 - val_accuracy: 0.7083
# Epoch 17/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.5798 - accuracy: 0.7152 - val_loss: 0.6900 - val_accuracy: 0.5139
# Epoch 18/20
# 10/10 [==============================] - 22s 2s/step - loss: 0.5673 - accuracy: 0.7057 - val_loss: 0.6609 - val_accuracy: 0.5417
# Epoch 19/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.6008 - accuracy: 0.6361 - val_loss: 0.6455 - val_accuracy: 0.6250
# Epoch 20/20
# 10/10 [==============================] - 23s 2s/step - loss: 0.5533 - accuracy: 0.7120 - val_loss: 0.6581 - val_accuracy: 0.5417

# %%
# Plot Gender Model Loss Curve
plt.figure()
plt.plot(history_gender.history['loss'], label='Train Loss')
plt.plot(history_gender.history['val_loss'], label='Validation Loss')
plt.title('RESNET101 Gender Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('RESNET101 Gender Model - Loss Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# Plot Gender Model Accuracy Curve
plt.figure()
plt.plot(history_gender.history['accuracy'], label='Train Accuracy')
plt.plot(history_gender.history['val_accuracy'], label='Validation Accuracy')
plt.title('RESNET101 Gender Model - Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('RESNET101 Gender Model - Accuracy Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# Gender Model - ROC Curve on Validation
y_val_gender_pred_prob = gender_model.predict(X_val).ravel()
val_fpr, val_tpr, _ = roc_curve(y_val_gender, y_val_gender_pred_prob)
roc_auc = auc(val_fpr, val_tpr)

plt.figure()
plt.plot(val_fpr, val_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('RESNET101 Gender Model - ROC Curve on Validation Set')
plt.legend(loc="lower right")
plt.savefig('RESNET101 Gender Model - ROC Curve on Validation Set.png', bbox_inches='tight')  # Save the figure
plt.show()
# Out:
# 3/3 [==============================] - 6s 1s/step

# %%
# Age Model - ResNet101
def create_age_model(input_shape=(224, 224, 3)):
    base_model = ResNet101(include_top=False, input_shape=input_shape)  # Changed to ResNet101
    for layer in base_model.layers:
        layer.trainable = False
    x = base_model.output
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(1)(x)
    model = Model(inputs=base_model.input, outputs=output)
    return model

age_model = create_age_model()
age_model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])

# Train Age Model
history_age = age_model.fit(X_train_age, y_train_age_balanced, validation_data=(X_val, y_val_age),
                            epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 69s 2s/step - loss: 656.5057 - mae: 21.0442 - val_loss: 370.4510 - val_mae: 15.8862
# Epoch 2/20
# 31/31 [==============================] - 61s 2s/step - loss: 412.9318 - mae: 17.3906 - val_loss: 405.4734 - val_mae: 16.6087
# Epoch 3/20
# 31/31 [==============================] - 64s 2s/step - loss: 391.8691 - mae: 16.9276 - val_loss: 377.2917 - val_mae: 16.0253
# Epoch 4/20
# 31/31 [==============================] - 60s 2s/step - loss: 373.3840 - mae: 16.4559 - val_loss: 344.1688 - val_mae: 15.3245
# Epoch 5/20
# 31/31 [==============================] - 63s 2s/step - loss: 352.0828 - mae: 15.9771 - val_loss: 330.1920 - val_mae: 15.0143
# Epoch 6/20
# 31/31 [==============================] - 60s 2s/step - loss: 335.3066 - mae: 15.5924 - val_loss: 332.4622 - val_mae: 15.1408
# Epoch 7/20
# 31/31 [==============================] - 61s 2s/step - loss: 317.6814 - mae: 15.1103 - val_loss: 331.3540 - val_mae: 15.2290
# Epoch 8/20
# 31/31 [==============================] - 62s 2s/step - loss: 300.2357 - mae: 14.6531 - val_loss: 279.1888 - val_mae: 13.6978
# Epoch 9/20
# 31/31 [==============================] - 61s 2s/step - loss: 287.4934 - mae: 14.3310 - val_loss: 284.0514 - val_mae: 13.9726
# Epoch 10/20
# 31/31 [==============================] - 62s 2s/step - loss: 273.1132 - mae: 13.8923 - val_loss: 270.4269 - val_mae: 13.5970
# Epoch 11/20
# 31/31 [==============================] - 60s 2s/step - loss: 259.8384 - mae: 13.5442 - val_loss: 254.6000 - val_mae: 13.0796
# Epoch 12/20
# 31/31 [==============================] - 62s 2s/step - loss: 248.3054 - mae: 13.1867 - val_loss: 242.1272 - val_mae: 12.7438
# Epoch 13/20
# 31/31 [==============================] - 62s 2s/step - loss: 237.9481 - mae: 12.9391 - val_loss: 248.1783 - val_mae: 13.0551
# Epoch 14/20
# 31/31 [==============================] - 61s 2s/step - loss: 228.9985 - mae: 12.6616 - val_loss: 248.4204 - val_mae: 13.1420
# Epoch 15/20
# 31/31 [==============================] - 62s 2s/step - loss: 222.9306 - mae: 12.4732 - val_loss: 223.6372 - val_mae: 12.3079
# Epoch 16/20
# 31/31 [==============================] - 61s 2s/step - loss: 213.4191 - mae: 12.1525 - val_loss: 228.8205 - val_mae: 12.5121
# Epoch 17/20
# 31/31 [==============================] - 61s 2s/step - loss: 203.7677 - mae: 11.9252 - val_loss: 209.2111 - val_mae: 11.8221
# Epoch 18/20
# 31/31 [==============================] - 61s 2s/step - loss: 201.1164 - mae: 11.7260 - val_loss: 221.7767 - val_mae: 12.3556
# Epoch 19/20
# 31/31 [==============================] - 61s 2s/step - loss: 190.0930 - mae: 11.4864 - val_loss: 213.9672 - val_mae: 12.1123
# Epoch 20/20
# 31/31 [==============================] - 62s 2s/step - loss: 188.2330 - mae: 11.3327 - val_loss: 201.3383 - val_mae: 11.6407

# %%
# Plot Age Model Loss Curve
plt.figure()
plt.plot(history_age.history['loss'], label='Train Loss')
plt.plot(history_age.history['val_loss'], label='Validation Loss')
plt.title('RESNET101 Age Model - Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('RESNET101 Age Model - Loss Curve.png', bbox_inches='tight')  # Save the figure
plt.show()

# %%
# Load test images
test_image_paths = []
test_age_labels = []
test_gender_labels = []
test_image_ids = []

for filename in os.listdir(test_dir):
    image_path = os.path.join(test_dir, filename)
    temp = filename.split('_')
    image_id = temp[0]
    gender = int(temp[1])
    age = int(temp[2].split()[0])
    test_image_paths.append(image_path)
    test_age_labels.append(age)
    test_gender_labels.append(gender)
    test_image_ids.append(image_id)

test_df = pd.DataFrame({'image': test_image_paths, 'age': test_age_labels, 'gender': test_gender_labels, 'image_id': test_image_ids})
X_test_images = load_images(test_df['image'])
y_test_gender = np.array(test_df['gender'])
y_test_age = np.array(test_df['age'])
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]

# %%
# Gender Model - Test Set Evaluation
y_pred_gender_test_prob = gender_model.predict(X_test_images).ravel()
y_pred_gender_test = (y_pred_gender_test_prob > 0.5).astype(int)

# Calculate ROC Curve
test_fpr, test_tpr, _ = roc_curve(y_test_gender, y_pred_gender_test_prob)
test_roc_auc = auc(test_fpr, test_tpr)

# Print classification report
print("Gender Test Classification Report:\n", classification_report(y_test_gender, y_pred_gender_test))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_gender, y_pred_gender_test)
print("Confusion Matrix:\n", conf_matrix)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Female', 'Male'], yticklabels=['Female', 'Male'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('RESNET101 Gender Model Confusion Matrix')
plt.savefig('RESNET101 Gender Model Confusion Matrix.png', bbox_inches='tight')  # Save the figure
plt.show()

# Plot ROC Curve
plt.figure()
plt.plot(test_fpr, test_tpr, color='blue', lw=2, label=f'ROC curve (AUC = {test_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('RESNET101 Gender Model - ROC Curve on Test Set')
plt.legend(loc="lower right")
plt.savefig('RESNET101 Gender Model - ROC Curve on Test Set.png', bbox_inches='tight')  # Save the figure
plt.show()
# Out:
# 3/3 [==============================] - 4s 1s/step
# Gender Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.49      0.60        41
#            1       0.60      0.84      0.70        38
#
#     accuracy                           0.66        79
#    macro avg       0.69      0.66      0.65        79
# weighted avg       0.69      0.66      0.65        79
#
# Confusion Matrix:
#  [[20 21]
#  [ 6 32]]

# %%
# Age Model - Test Set Evaluation
y_pred_age_test = age_model.predict(X_test_images).ravel()

# Evaluation metrics for Age Model
mse_age = mean_squared_error(y_test_age, y_pred_age_test)
mae_age = mean_absolute_error(y_test_age, y_pred_age_test)
mape_age = mean_absolute_percentage_error(y_test_age, y_pred_age_test)
rmse_age = np.sqrt(mse_age)
r2_age = r2_score(y_test_age, y_pred_age_test)

print("Age Model Evaluation:")
print(f"MSE: {mse_age:.2f}")
print(f"MAE: {mae_age:.2f}")
print(f"MAPE: {mape_age:.2%}")
print(f"RMSE: {rmse_age:.2f}")
print(f"R^2 Score: {r2_age:.2f}")

# Plotting Age Predictions
plt.figure(figsize=(10, 5))
plt.scatter(y_test_age, y_pred_age_test, alpha=0.5)
plt.plot([y_test_age.min(), y_test_age.max()], [y_test_age.min(), y_test_age.max()], 'k--', lw=2)
plt.title('Actual vs Predicted Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.show()
# Out:
# 3/3 [==============================] - 7s 2s/step
# Age Model Evaluation:
# MSE: 170.68
# MAE: 10.62
# MAPE: 38.16%
# RMSE: 13.06
# R^2 Score: 0.15
